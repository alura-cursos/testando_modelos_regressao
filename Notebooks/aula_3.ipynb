# %% [markdown]
# <a href="https://colab.research.google.com/github/vqrca/testando_modelos_regressao/blob/main/Notebooks/aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1: Regressão linear múltipla**

# %% [markdown]
# ##**Conhecendo e preparando os dados**

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
url <- 'https://raw.githubusercontent.com/alura-cursos/testando_modelos_regressao/refs/heads/main/Dados/automoveis_usados.csv'

# %%
dados <- read.csv(url)

# %%
head(dados)
# Out:
#   Estilo                  Ano  Potencia_motor Cilindros_motor
# 1 SUV 4 portas            2005 275            6
# 2 seda                    2016 170            4
# 3 minivan de passageiros  2016 248            6
# 4 seda                    2015 138            4
# 5 seda                    1991 162            4
# 6 picape cabine estendida 2012 152            4
#   Consumo_estrada_km Valor
# 1 28.96812           29695
# 2 61.15492           30495
# 3 45.06152           37650
# 4 57.93624           16170
# 5 32.18680            2000
# 6 37.01482           19299

# %%
any(is.na(dados))
# Out:
# [1] FALSE

# %%
dados <- dados %>%
  mutate(Estilo = as.factor(Estilo))

# %%
glimpse(dados)
# Out:
# Rows: 10,819
# Columns: 6
# $ Estilo             <fct> SUV 4 portas, seda, minivan de passageiros, seda, s…
# $ Ano                <int> 2005, 2016, 2016, 2015, 1991, 2012, 2016, 1994, 199…
# $ Potencia_motor     <dbl> 275, 170, 248, 138, 162, 152, 365, 230, 205, 155, 1…
# $ Cilindros_motor    <dbl> 6, 4, 6, 4, 4, 4, 6, 6, 6, 4, 4, 6, 4, 4, 6, 4, 6, …
# $ Consumo_estrada_km <dbl> 28.96812, 61.15492, 45.06152, 57.93624, 32.18680, 3…
# $ Valor              <int> 29695, 30495, 37650, 16170, 2000, 19299, 42600, 238…

# %%
summary(dados)
# Out:
#                      Estilo          Ano       Potencia_motor  Cilindros_motor
#  seda                   :2780   Min.   :1990   Min.   : 55.0   Min.   : 3.000
#  SUV 4 portas           :2309   1st Qu.:2006   1st Qu.:169.0   1st Qu.: 4.000
#  cupe                   : 854   Median :2014   Median :210.0   Median : 6.000
#  picape cabine dupla    : 681   Mean   :2010   Mean   :228.1   Mean   : 5.379
#  hatchback 4 portas     : 665   3rd Qu.:2016   3rd Qu.:285.0   3rd Qu.: 6.000
#  picape cabine estendida: 623   Max.   :2017   Max.   :707.0   Max.   :12.000
#  (Other)                :2907
#  Consumo_estrada_km     Valor
#  Min.   :19.31      Min.   : 2000
#  1st Qu.:35.41      1st Qu.:19999
#  Median :41.84      Median :28410
#  Mean   :42.96      Mean   :28609
#  3rd Qu.:49.89      3rd Qu.:38190
#  Max.   :85.30      Max.   :74000

# %% [markdown]
# ##**Analisando a relação entre as variáveis**

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

# %%
dados %>%
  group_by(Estilo) %>%
  summarise(media_valor = mean(Valor)) %>%
  ggplot(aes(x = reorder(Estilo, media_valor), y = media_valor)) +
  geom_col() +
  coord_flip() +
    labs(title = 'Média do valor por estilo do automóvel',
         x = '',
         y = 'Média do valor') +
           theme(text = element_text(size = 16))
# Out:
# plot without title

# %%
ggplot(dados, aes(x = Ano, y = Valor)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(dados, aes(x = Potencia_motor, y = Valor)) +
  geom_point() +
    geom_smooth(method = 'lm', se = FALSE, color = 'red')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
ggplot(dados, aes(x = Cilindros_motor, y = Valor)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(dados, aes(x = Consumo_estrada_km, y = Valor)) +
  geom_point()
# Out:
# plot without title

# %%
dados_numericos <- dados %>% select_if(is.numeric)

matriz_correlacao <- cor(dados_numericos)

matriz_correlacao
# Out:
#                    Ano        Potencia_motor Cilindros_motor Consumo_estrada_km
# Ano                 1.0000000  0.3890908     -0.1065934       0.35776466
# Potencia_motor      0.3890908  1.0000000      0.6952144      -0.43319516
# Cilindros_motor    -0.1065934  0.6952144      1.0000000      -0.70162167
# Consumo_estrada_km  0.3577647 -0.4331952     -0.7016217       1.00000000
# Valor               0.6966555  0.7361250      0.3040547      -0.04757501
#                    Valor
# Ano                 0.69665546
# Potencia_motor      0.73612504
# Cilindros_motor     0.30405466
# Consumo_estrada_km -0.04757501
# Valor               1.00000000

# %% [markdown]
# ##**Construindo o modelo de regressão linear múltipla**

# %%
modelo_linear_simples <- lm(Valor ~ Potencia_motor, data = dados)

summary(modelo_linear_simples)
# Out:
# Call:
# lm(formula = Valor ~ Potencia_motor, data = dados)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -50886  -5112   1506   6183  42714
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -4494.228    310.542  -14.47   <2e-16 ***
# Potencia_motor   145.125      1.283  113.11   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 10800 on 10817 degrees of freedom
# Multiple R-squared:  0.5419,	Adjusted R-squared:  0.5418
# F-statistic: 1.279e+04 on 1 and 10817 DF,  p-value: < 2.2e-16

# %%
plot(modelo_linear_simples, which=1)
# Out:
# Plot with title “”

# %%
plot(modelo_linear_simples, which=2)
# Out:
# Plot with title “”

# %%
modelo_linear_multiplo <- lm(Valor ~ ., data= dados)

summary(modelo_linear_multiplo)
# Out:
# Call:
# lm(formula = Valor ~ ., data = dados)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -30733  -4994   -517   4499  39640
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -1.882e+06  3.350e+04 -56.184  < 2e-16 ***
# Estilocupe                    -7.247e+03  4.228e+02 -17.141  < 2e-16 ***
# Estilohatchback 2 portas      -6.511e+03  4.796e+02 -13.578  < 2e-16 ***
# Estilohatchback 4 portas      -7.363e+03  4.538e+02 -16.226  < 2e-16 ***
# Estilominivan de carga        -6.454e+03  9.881e+02  -6.531 6.81e-11 ***
# Estilominivan de passageiros  -4.768e+03  5.126e+02  -9.301  < 2e-16 ***
# Estiloperua                   -4.246e+03  4.568e+02  -9.296  < 2e-16 ***
# Estilopicape cabine dupla     -8.134e+03  4.715e+02 -17.252  < 2e-16 ***
# Estilopicape cabine estendida -1.134e+04  4.826e+02 -23.495  < 2e-16 ***
# Estilopicape cabine simples   -1.100e+04  5.298e+02 -20.765  < 2e-16 ***
# Estiloseda                    -4.824e+03  3.596e+02 -13.418  < 2e-16 ***
# EstiloSUV 2 portas            -6.521e+03  7.558e+02  -8.628  < 2e-16 ***
# EstiloSUV 4 portas            -2.944e+03  3.772e+02  -7.805 6.48e-15 ***
# EstiloSUV Conversível          9.691e+02  1.470e+03   0.659   0.5098
# Estilovan de carga            -1.162e+04  8.937e+02 -13.007  < 2e-16 ***
# Estilovan de passageiros      -9.242e+03  8.035e+02 -11.502  < 2e-16 ***
# Ano                            9.418e+02  1.696e+01  55.535  < 2e-16 ***
# Potencia_motor                 1.094e+02  1.977e+00  55.348  < 2e-16 ***
# Cilindros_motor               -1.260e+02  1.004e+02  -1.255   0.2096
# Consumo_estrada_km            -3.207e+01  1.594e+01  -2.012   0.0442 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7667 on 10799 degrees of freedom
# Multiple R-squared:  0.7697,	Adjusted R-squared:  0.7692
# F-statistic:  1899 on 19 and 10799 DF,  p-value: < 2.2e-16

# %% [markdown]
# #**Aula 2: Árvore de decisão**

# %% [markdown]
# ##**Separando os dados em treino e teste**

# %%
install.packages('tidymodels')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘shape’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘prodlim’, ‘warp’, ‘future.apply’, ‘iterators’, ‘listenv’, ‘parallelly’, ‘lhs’, ‘DiceDesign’, ‘sfd’, ‘patchwork’, ‘globals’, ‘clock’, ‘gower’, ‘ipred’, ‘timeDate’, ‘furrr’, ‘slider’, ‘doFuture’, ‘foreach’, ‘future’, ‘GPfit’, ‘modelenv’, ‘dials’, ‘hardhat’, ‘infer’, ‘modeldata’, ‘parsnip’, ‘recipes’, ‘rsample’, ‘tune’, ‘workflows’, ‘workflowsets’, ‘yardstick’

# %%
library(tidymodels)
# Out:
# ── Attaching packages ────────────────────────────────────── tidymodels 1.2.0 ──
#
# ✔ broom        1.0.7     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.2.1
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.1.0
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Learn how to get started at https://www.tidymodels.org/start/

# %%
set.seed(6578)

df_split <- initial_split(dados, prop = 0.8)
df_split
# Out:
# <Training/Testing/Total>
# <8655/2164/10819>

# %%
df_treino <- training(df_split)
df_teste <- testing(df_split)

# %% [markdown]
# ##**Treinando o modelo**

# %%
arvore <- decision_tree() %>%
  set_engine('rpart') %>%
  set_mode('regression')

# %%
set.seed(4556)

modelo_arvore_decisao <- arvore %>%
  fit(Valor ~ Estilo + Ano + Potencia_motor, data = df_treino)

# %%
modelo_arvore_decisao
# Out:
# parsnip model object
#
# n= 8655
#
# node), split, n, deviance, yval
#       * denotes terminal node
#
#  1) root 8655 2.211151e+12 28564.100
#    2) Ano< 2000.5 1344 6.595049e+09  2526.276 *
#    3) Ano>=2000.5 7311 1.125860e+12 33350.700
#      6) Potencia_motor< 216 3344 1.287282e+11 24209.120
#       12) Potencia_motor< 166.5 1392 2.697496e+10 19965.940 *
#       13) Potencia_motor>=166.5 1952 5.881843e+10 27235.000 *
#      7) Potencia_motor>=216 3967 4.821132e+11 41056.630
#       14) Potencia_motor< 310.5 2800 2.144520e+11 37429.220
#         28) Estilo=hatchback 2 portas,minivan de carga,minivan de passageiros,picape cabine dupla,picape cabine estendida,picape cabine simples,van de carga 677 1.777117e+10 32227.800 *
#         29) Estilo=conversivel,cupe,hatchback 4 portas,perua,seda,SUV 2 portas,SUV 4 portas,SUV Conversível,van de passageiros 2123 1.725240e+11 39087.890 *
#       15) Potencia_motor>=310.5 1167 1.424214e+11 49759.920
#         30) Estilo=cupe,perua,picape cabine dupla,picape cabine estendida,picape cabine simples 565 5.071966e+10 44582.290 *
#         31) Estilo=conversivel,hatchback 4 portas,seda,SUV 4 portas 602 6.233971e+10 54619.330 *

# %%
install.packages('rpart.plot')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(rpart.plot)
# Out:
# Loading required package: rpart
#
#
# Attaching package: ‘rpart’
#
#
# The following object is masked from ‘package:dials’:
#
#     prune

# %%
arvore_plot <- rpart.plot(modelo_arvore_decisao$fit, roundint = FALSE, cex = 0.8)
# Out:
# plot without title

# %%
arvore_3 <- decision_tree(tree_depth = 3) %>%
  set_engine('rpart') %>%
  set_mode('regression')

# %%
set.seed(4556)

modelo_arvore_decisao_3 <- arvore %>%
  fit(Valor ~ Estilo + Ano + Potencia_motor, data = df_treino)

# %%
arvore_3_plot <- rpart.plot(modelo_arvore_decisao_3$fit, roundint = FALSE, cex = 0.8)
# Out:
# plot without title

# %% [markdown]
# ##**Avaliando a performance do modelo**

# %%
predicoes <- predict(modelo_arvore_decisao, new_data = df_teste)

# %%
predicoes
# Out:
#      .pred
# 1    19965.935
# 2    39087.894
# 3    27234.996
# 4     2526.276
# 5    27234.996
# 6    39087.894
# 7    27234.996
# 8    19965.935
# 9    27234.996
# 10   19965.935
# 11   27234.996
# 12   27234.996
# 13   39087.894
# 14   27234.996
# 15   39087.894
# 16   27234.996
# 17   27234.996
# 18   44582.288
# 19   19965.935
# 20   27234.996
# 21    2526.276
# 22   39087.894
# 23   44582.288
# 24   39087.894
# 25   27234.996
# 26   39087.894
# 27   19965.935
# 28   19965.935
# 29   39087.894
# 30   39087.894
# ⋮    ⋮
# 2135 54619.331
# 2136  2526.276
# 2137 19965.935
# 2138 27234.996
# 2139 27234.996
# 2140 39087.894
# 2141 32227.801
# 2142 44582.288
# 2143 44582.288
# 2144 39087.894
# 2145 44582.288
# 2146 39087.894
# 2147 27234.996
# 2148 32227.801
# 2149 39087.894
# 2150  2526.276
# 2151 27234.996
# 2152 27234.996
# 2153 27234.996
# 2154 44582.288
# 2155  2526.276
# 2156 39087.894
# 2157 19965.935
# 2158  2526.276
# 2159 32227.801
# 2160  2526.276
# 2161 39087.894
# 2162 27234.996
# 2163  2526.276
# 2164 27234.996

# %%
predicoes_arvore <- bind_cols(df_teste, predicoes)

# %%
predicoes_arvore
# Out:
#      Estilo                  Ano  Potencia_motor Cilindros_motor
# 1    hatchback 2 portas      2015 106            4
# 2    seda                    2008 264            6
# 3    hatchback 2 portas      2005 210            4
# 4    perua                   1991 162            4
# 5    SUV 4 portas            2017 168            4
# 6    SUV 4 portas            2017 284            6
# 7    SUV 2 portas            2001 203            6
# 8    hatchback 4 portas      2016 138            4
# 9    hatchback 2 portas      2013 200            4
# 10   hatchback 4 portas      2017 164            4
# 11   minivan de passageiros  2005 200            6
# 12   seda                    2016 184            4
# 13   SUV 4 portas            2017 240            4
# 2138 25.74944           26195 27234.996
# 2139 37.01482           31105 27234.996
# 2140 38.62416           31200 39087.894
# 2141 27.35878           32155 32227.801
# 2142 27.35878           32170 44582.288
# 2143 37.01482           34995 44582.288
# 2144 46.67086           35705 39087.894
# 2145 38.62416           33750 44582.288
# 2146 54.71756           38400 39087.894
# 2147 49.88954           20595 27234.996
# 2148 30.57746           32690 32227.801
# 2149 53.10822           33200 39087.894
# 2150 38.62416            2000  2526.276
# 2151 49.88954           28795 27234.996
# 2152 51.49888           19800 27234.996
# 2153 40.23350           24690 27234.996
# 2154 33.79614           50305 44582.288
# 2155 41.84284            2000  2526.276
# 2156 35.40548           34005 39087.894
# 2157 49.88954           20090 19965.935
# 2158 28.96812            2992  2526.276
# 2159 37.01482           23280 32227.801
# 2160 40.23350            2000  2526.276
# 2161 40.23350           49150 39087.894
# 2162 49.88954           25450 27234.996
# 2163 37.01482            2575  2526.276
# 2164 48.28020           41300 27234.996

# %%
rsq(predicoes_arvore,
    estimate = .pred,
    truth = Valor)
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.820248

# %%
mae(predicoes_arvore,
    estimate = .pred,
    truth = Valor)
# Out:
#   .metric .estimator .estimate
# 1 mae     standard   4783.037

# %%
rmse(predicoes_arvore,
    estimate = .pred,
    truth = Valor)
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   6727.974

# %%
calcular_metricas <- function(predicoes, valores_reais) {
  resultado <- tibble(
    predicao = predicoes,
    real = valores_reais
  )

  metricas <- resultado %>%
    metrics(truth = real, estimate = predicao)

  return(metricas)
}

# %%
metricas_arvore <- calcular_metricas(predicoes_arvore$.pred, df_teste$Valor)
metricas_arvore
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   6727.974202
# 2 rsq     standard      0.820248
# 3 mae     standard   4783.037334

# %% [markdown]
# ##**Aplicando a técnica de validação cruzada**

# %% [markdown]
# ![ID_img_2.3.jpg](data:image/jpeg;base64,...)

# %%
set.seed(4556)

df_folds <- vfold_cv(df_treino, v = 5)

# %%
set.seed(4456)

fits_cv <- fit_resamples(arvore,
                         Valor ~ Estilo + Ano + Potencia_motor,
                         resamples = df_folds,
                         metrics = metric_set(rmse, mae, rsq))

# %%
metricas_cv <- collect_metrics(fits_cv, summarize = FALSE)
metricas_cv
# Out:
#    id    .metric .estimator .estimate    .config
# 1  Fold1 rmse    standard   6666.1452563 Preprocessor1_Model1
# 2  Fold1 mae     standard   4770.0714765 Preprocessor1_Model1
# 3  Fold1 rsq     standard      0.8289911 Preprocessor1_Model1
# 4  Fold2 rmse    standard   6857.5945569 Preprocessor1_Model1
# 5  Fold2 mae     standard   4788.4718165 Preprocessor1_Model1
# 6  Fold2 rsq     standard      0.8196698 Preprocessor1_Model1
# 7  Fold3 rmse    standard   6773.7672352 Preprocessor1_Model1
# 8  Fold3 mae     standard   4782.4624105 Preprocessor1_Model1
# 9  Fold3 rsq     standard      0.8203407 Preprocessor1_Model1
# 10 Fold4 rmse    standard   6933.9370562 Preprocessor1_Model1
# 11 Fold4 mae     standard   4855.8504832 Preprocessor1_Model1
# 12 Fold4 rsq     standard      0.8111651 Preprocessor1_Model1
# 13 Fold5 rmse    standard   6746.4905738 Preprocessor1_Model1
# 14 Fold5 mae     standard   4720.2215285 Preprocessor1_Model1
# 15 Fold5 rsq     standard      0.8152714 Preprocessor1_Model1

# %%
media_metricas_arvore <- collect_metrics(fits_cv)
media_metricas_arvore
# Out:
#   .metric .estimator mean         n std_err      .config
# 1 mae     standard   4783.4155430 5 21.731132630 Preprocessor1_Model1
# 2 rmse    standard   6795.5869357 5 46.166763686 Preprocessor1_Model1
# 3 rsq     standard      0.8190876 5  0.002977559 Preprocessor1_Model1

# %% [markdown]
# #**Aula 3: Técnicas de Ensemble**

# %% [markdown]
# ##**Aplicando a técnica de Bagging**

# %% [markdown]
# ![eva_aUWXZpO.jpg](data:image/jpeg;base64,...)

# %%
install.packages('baguette')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages('ranger')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(baguette)
library(ranger)

# %%
bagging <- bag_tree() %>%
  set_mode('regression') %>%
  set_engine('rpart', times = 100)

# %%
set.seed(4556)

modelo_bagging <- bagging %>%
  fit(Valor ~ Estilo + Ano + Potencia_motor, data = df_treino)

# %%
modelo_bagging
# Out:
# parsnip model object
#
# Bagged CART (regression with 100 members)
#
# Variable importance scores include:
#
# # A tibble: 3 × 4
#   term             value   std.error  used
#   <chr>            <dbl>       <dbl> <int>
# 1 Ano            1.24e12 2188886368.   100
# 2 Potencia_motor 9.77e11 2166065457.   100
# 3 Estilo         3.19e11 1250656068.   100

# %%
predicoes <- predict(modelo_bagging, new_data = df_teste)

# %%
predicoes_bagging <- bind_cols(df_teste, predicoes)

# %%
predicoes_bagging
# Out:
#      Estilo                  Ano  Potencia_motor Cilindros_motor
# 1    hatchback 2 portas      2015 106            4
# 2    seda                    2008 264            6
# 3    hatchback 2 portas      2005 210            4
# 4    perua                   1991 162            4
# 5    SUV 4 portas            2017 168            4
# 6    SUV 4 portas            2017 284            6
# 7    SUV 2 portas            2001 203            6
# 8    hatchback 4 portas      2016 138            4
# 9    hatchback 2 portas      2013 200            4
# 10   hatchback 4 portas      2017 164            4
# 11   minivan de passageiros  2005 200            6
# 12   seda                    2016 184            4
# 13   SUV 4 portas            2017 240            4
# 14   hatchback 4 portas      2016 188            4
# 15   seda                    2016 304            6
# 16   seda                    2016 178            4
# 17   seda                    2016 195            4
# 18   picape cabine estendida 2017 385            8
# 19   picape cabine simples   2003 135            4
# 20   SUV 4 portas            2016 176            4
# 21   seda                    1995 225            6
# 22   seda                    2015 272            4
# 23   cupe                    2009 330            6
# 24   SUV 4 portas            2013 265            6
# 25   seda                    2017 200            4
# 26   SUV 4 portas            2017 250            4
# 27   SUV 4 portas            2011 166            4
# 28   hatchback 4 portas      2012 158            4
# 29   SUV 2 portas            2016 240            4
# 30   seda                    2004 225            4
# ⋮    ⋮                       ⋮    ⋮              ⋮
# 2135 SUV 4 portas            2016 420            8
# 2136 picape cabine simples   1999 220            8
# 2137 picape cabine simples   2002 120            4
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   4562.5555314
# 2 rsq     standard      0.9173159
# 3 mae     standard   3022.3345081

# %% [markdown]
# ##**Avaliando a performance do modelo bagging**

# %%
set.seed(4456)

fits_cv <- fit_resamples(bagging,
                         Valor ~ Estilo + Ano + Potencia_motor,
                         resamples = df_folds,
                         metrics = metric_set(rmse, mae, rsq))

# %%
media_metricas_bagging <- collect_metrics(fits_cv)
media_metricas_bagging
# Out:
#   .metric .estimator mean         n std_err      .config
# 1 mae     standard   2976.3107396 5 27.659366111 Preprocessor1_Model1
# 2 rmse    standard   4577.5347408 5 73.064356401 Preprocessor1_Model1
# 3 rsq     standard      0.9179594 5  0.002374638 Preprocessor1_Model1

# %% [markdown]
# ##**Construindo um modelo com Random forest**

# %%
install.packages('randomForest')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(randomForest)
# Out:
# randomForest 4.7-1.2
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:ranger’:
#
#     importance
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %%
floresta_aleatoria <- rand_forest(trees = 100) %>%
  set_mode('regression') %>%
  set_engine('ranger')

# %%
set.seed(4456)

modelo_floresta_aleatoria <- floresta_aleatoria %>%
  fit(Valor ~ Estilo + Ano + Potencia_motor, data = df_treino)

# %%
modelo_floresta_aleatoria
# Out:
# parsnip model object
#
# Ranger result
#
# Call:
#  ranger::ranger(x = maybe_data_frame(x), y = y, num.trees = ~100,      num.threads = 1, verbose = FALSE, seed = sample.int(10^5,          1))
#
# Type:                             Regression
# Number of trees:                  100
# Sample size:                      8655
# Number of independent variables:  3
# Mtry:                             1
# Target node size:                 5
# Variable importance mode:         none
# Splitrule:                        variance
# OOB prediction error (MSE):       27633249
# R squared (OOB):                  0.891849

# %%
predicoes <- predict(modelo_floresta_aleatoria, new_data = df_teste)

# %%
predicoes_floresta <- bind_cols(df_teste, predicoes)

# %%
metricas_floresta <- calcular_metricas(predicoes_floresta$.pred, predicoes_floresta$Valor)
metricas_floresta
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   5288.1087367
# 2 rsq     standard      0.8930113
# 3 mae     standard   3596.6924404

# %% [markdown]
# ##**Avaliando a performance do modelo Random forest**

# %%
floresta_aleatoria <- rand_forest(trees = 100, mtry = 2) %>%
  set_mode('regression') %>%
  set_engine('ranger')

# %%
set.seed(4456)

fits_cv <- fit_resamples(floresta_aleatoria,
                         Valor ~ Estilo + Ano + Potencia_motor,
                         resamples = df_folds,
                         metrics = metric_set(rmse, mae, rsq))

# %%
media_metricas_floresta <- collect_metrics(fits_cv)
media_metricas_floresta
# Out:
#   .metric .estimator mean         n std_err     .config
# 1 mae     standard   2967.5366347 5 32.89725001 Preprocessor1_Model1
# 2 rmse    standard   4529.9875247 5 69.05623909 Preprocessor1_Model1
# 3 rsq     standard      0.9196103 5  0.00207145 Preprocessor1_Model1
